# %% [markdown]
# GitHub:https://github.com/wotchin/SimilarVocabulary
#
# 掘金：https://juejin.im/entry/5be4286b6fb9a049f745b0c5?utm_source=gold_browser_extension

# %%
import spacy

nlp = spacy.load('en_core_web_lg')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-e3fab841dec7> in <module>()
# ----> 1 import spacy
#       2
#       3 nlp = spacy.load('en_core_web_lg')
#
# ModuleNotFoundError: No module named 'spacy'

# %%
# !pip3 install spacy
# Out:
# ...
#     100% |████████████████████████████████| 25.6MB 902kB/s ta 0:00:011   29% |█████████▌                      | 7.6MB 810kB/s eta 0:00:23
# ...
#     100% |████████████████████████████████| 153kB 823kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 1.1MB/s ta 0:00:011
# ...
#     100% |████████████████████████████████| 194kB 868kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 2.6MB 801kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 614kB 586kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 153kB 808kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 143kB 889kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 51kB 862kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 450kB 999kB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 51kB 2.0MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for ujson ... error
# ...
